# %% [markdown]
# 之後可以刪除此檔案，用作測試。

# %%
# 假設檔名為 data.tsv
with open("../../coliee_dataset/task1/lht_process/modernBert/output_modernBert_cos_train.tsv", "r", encoding="utf-8") as f:
    for i in range(10):
        line = f.readline()
        if not line:  # 如果檔案不足10行就停止
            break
        print(line.strip())  # 去掉換行符號
# Out:
# 008447 Q0 062926 1 0.9697265625 modernBert_cos
# 008447 Q0 010465 2 0.96240234375 modernBert_cos
# 008447 Q0 048578 3 0.9599609375 modernBert_cos
# 008447 Q0 088958 4 0.95849609375 modernBert_cos
# 008447 Q0 038264 5 0.95751953125 modernBert_cos
# 008447 Q0 079263 6 0.95654296875 modernBert_cos
# 008447 Q0 014587 7 0.95654296875 modernBert_cos
# 008447 Q0 051820 8 0.9560546875 modernBert_cos
# 008447 Q0 097435 9 0.95556640625 modernBert_cos
# 008447 Q0 008447 10 0.95556640625 modernBert_cos

# %%
# 假設檔名為 data.tsv
with open("../../coliee_dataset/task1/lht_process/BM25/output_bm25_train.tsv", "r", encoding="utf-8") as f:
    for i in range(10):
        line = f.readline()
        if not line:  # 如果檔案不足10行就停止
            break
        print(line.strip())  # 去掉換行符號
