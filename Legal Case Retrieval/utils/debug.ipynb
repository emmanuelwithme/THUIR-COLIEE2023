# %% [markdown]
# 之後可以刪除此檔案，用作測試。

# %%
# 假設檔名為 data.tsv
with open("../../coliee_dataset/task1/lht_process/modernBert/output_modernBert_cos_train.tsv", "r", encoding="utf-8") as f:
    for i in range(10):
        line = f.readline()
        if not line:  # 如果檔案不足10行就停止
            break
        print(line.strip())  # 去掉換行符號
# Out:
# 008447 Q0 008447 1 1.0 modernBert_cos
# 008447 Q0 089987 2 0.9658203125 modernBert_cos
# 008447 Q0 049315 3 0.896484375 modernBert_cos
# 008447 Q0 095905 4 0.880859375 modernBert_cos
# 008447 Q0 075040 5 0.865234375 modernBert_cos
# 008447 Q0 069049 6 0.85791015625 modernBert_cos
# 008447 Q0 072495 7 0.8427734375 modernBert_cos
# 008447 Q0 051992 8 0.8154296875 modernBert_cos
# 008447 Q0 004851 9 0.8037109375 modernBert_cos
# 008447 Q0 041229 10 0.7978515625 modernBert_cos

# %%
# 假設檔名為 data.tsv
with open("../../coliee_dataset/task1/lht_process/BM25/output_bm25_train.tsv", "r", encoding="utf-8") as f:
    for i in range(10):
        line = f.readline()
        if not line:  # 如果檔案不足10行就停止
            break
        print(line.strip())  # 去掉換行符號
# Out:
# 31 Q0 000031 1 825.166626 Anserini
# 31 Q0 097609 2 393.092987 Anserini
# 31 Q0 074681 3 384.481201 Anserini
# 31 Q0 013059 4 351.335999 Anserini
# 31 Q0 022561 5 351.335999 Anserini
# 31 Q0 085737 6 345.514099 Anserini
# 31 Q0 091216 7 327.555115 Anserini
# 31 Q0 072571 8 327.345215 Anserini
# 31 Q0 037550 9 326.340698 Anserini
# 31 Q0 082589 10 319.084106 Anserini
